# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset_banco.csv')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no   2143.0     yes   no
# 1       44    technician    single  secondary      no     29.0     yes   no
# 2       33  entrepreneur   married  secondary      no      2.0     yes  yes
# 3       47   blue-collar   married    unknown      no   1506.0     yes   no
# 4       33       unknown    single    unknown      no      1.0      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45210   51    technician   married   tertiary      no    825.0      no   no
# 45211   71       retired  divorced    primary      no   1729.0      no   no
# 45212   72       retired   married  secondary      no   5715.0      no   no
# 45213   57   blue-collar   married  secondary      no    668.0      no   no
# 45214   37  entrepreneur   married  secondary      no   2971.0      no   no
#
# ...

# %%
df.shape
# Out:
# (45215, 17)

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45215.000000   45213.000000  45215.000000  45214.000000  45215.000000
# mean      41.004711    1374.159866     15.805839    258.074357      2.763729
# std       12.036647    3924.255525      8.322473    257.605175      3.097910
# min       18.000000   -8019.000000      1.000000  -1389.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max      776.000000  527532.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45214.000000  45215.000000
# mean      40.192485      0.580383
# std      100.120622      2.303438
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45215 entries, 0 to 45214
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45215 non-null  int64
#  1   job        45213 non-null  object
#  2   marital    45214 non-null  object
#  3   education  45214 non-null  object
#  4   default    45215 non-null  object
#  5   balance    45213 non-null  float64
#  6   housing    45215 non-null  object
#  7   loan       45215 non-null  object
#  8   contact    45215 non-null  object
#  9   day        45215 non-null  int64
#  10  month      45215 non-null  object
#  11  duration   45214 non-null  float64
#  12  campaign   45215 non-null  int64
#  13  pdays      45214 non-null  float64
#  14  previous   45215 non-null  int64
#  15  poutcome   45215 non-null  object
#  16  y          45215 non-null  object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 5.9+ MB

# %%
#eliminamos los nulos
df.dropna(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45207 entries, 0 to 45214
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45207 non-null  int64
#  1   job        45207 non-null  object
#  2   marital    45207 non-null  object
#  3   education  45207 non-null  object
#  4   default    45207 non-null  object
#  5   balance    45207 non-null  float64
#  6   housing    45207 non-null  object
#  7   loan       45207 non-null  object
#  8   contact    45207 non-null  object
#  9   day        45207 non-null  int64
#  10  month      45207 non-null  object
#  11  duration   45207 non-null  float64
#  12  campaign   45207 non-null  int64
#  13  pdays      45207 non-null  float64
#  14  previous   45207 non-null  int64
#  15  poutcome   45207 non-null  object
#  16  y          45207 non-null  object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 6.2+ MB

# %%
#contamos los niveles en las diferentes columnas

cols_cat = ['job', 'marital', 'education', 'default','housing', 'loan', 'contact','month','poutcome', 'y']

for col in cols_cat:
    print(f'Columna {col} tiene {df[col].nunique()} niveles' )
# Out:
# Columna job tiene 18 niveles
# Columna marital tiene 6 niveles
# Columna education tiene 10 niveles
# Columna default tiene 2 niveles
# Columna housing tiene 2 niveles
# Columna loan tiene 6 niveles
# Columna contact tiene 5 niveles
# Columna month tiene 12 niveles
# Columna poutcome tiene 6 niveles
# Columna y tiene 2 niveles

# %%
#eliminamos duplicados
df.drop_duplicates(inplace= True)
print(df.shape)
# Out:
# (45203, 17)

# %%
#observar mediante graficos si hay valores numericos anormales.

cols_num = ['age','balance','day','duration','previous']

for col in cols_num:
    plt.figure(figsize = (10,4))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
#eliminamos sujetos con mayores a 100 anios
df = df[df['age'] < 100]

# %%
#elinamos filas con duration de llamadas negativas
df = df[df['duration'] >0]

# %%
#eliminamos los previous extremadamentoa altos
df = df[df['previous']<100]
# Out:
# (45189, 17)

# %%
#graficar errores tipograficos en columnas categoricas.

cols_cat = ['job', 'marital', 'education', 'default','housing', 'loan', 'contact','month','poutcome', 'y']

for col in cols_cat:
    plt.figure(figsize=(12,4))
    sns.countplot(x=df[col])
    plt.title(col)
    plt.xticks(rotation = 90)
    plt.show()

# %%
#Pasamos todas las categorias a minuscula

for col in df.columns:
    if col in cols_cat:
        df[col] = df[col].str.lower()
        
for col in cols_cat:
    plt.figure(figsize=(10,4))
    sns.countplot(x=df[col])
    plt.title(col)
    plt.xticks(rotation=90)
    plt.show()

# %%
#job - Unificamos admin. y Administrative
print(df['job'].unique())
df['job'] = df['job'].str.replace('admin.', 'administrative', regex= False)
print(df['job'].unique())
# Out:
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student' 'administrative']
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'administrative' 'services' 'self-employed' 'unemployed'
#  'housemaid' 'student']

# %%
#marital
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student', 'administrative'],
#       dtype=object)

# %%
#marital - Unificamos div. divorced
print(df['marital'].unique())
df['marital'] = df['marital'].str.replace('div.', 'divorced', regex= False)
print(df['marital'].unique())
# Out:
# ['married' 'single' 'div.' 'divorced']
# ['married' 'single' 'divorced']

# %%
##education - unificamos sec. y secondary, y tambien unk con unknown
print(df['education'].unique())
df['education'] = df['education'].str.replace('sec.','secondary', regex = False)
df[df['education']== 'unk'] ='unknown'
print(df['education'].unique())
# Out:
# ['tertiary' 'secondary' 'unknown' 'primary' 'sec.' 'unk']
# ['tertiary' 'secondary' 'unknown' 'primary']
# C:\Users\maxiv\AppData\Local\Temp\ipykernel_2244\3807149009.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'unknown' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df[df['education']== 'unk'] ='unknown'
# C:\Users\maxiv\AppData\Local\Temp\ipykernel_2244\3807149009.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df[df['education']== 'unk'] ='unknown'

# %%
#contact - unificamos telephone y phone
df['contact'].unique()
df[df['contact'] =='phone'] = 'telephone'
df['contact'].unique()
# Out:
# array(['unknown', 'cellular', 'telephone', 'mobile'], dtype=object)

# %%
#poutcome: unificar unk con unknown
df['poutcome'].unique()
df[df['poutcome']== 'unk'] = 'unknown'
df['poutcome'].unique()
# Out:
# array(['unknown', 'failure', 'other', 'success', 'telephone'],
#       dtype=object)

# %%
#pasamos de 42215 registros a 45189 registros
# Out:
# (45189, 17)

# %%
#almacenamos en la misma carpeeta

df.to_csv('Data-Cleaning-Portfolio')
